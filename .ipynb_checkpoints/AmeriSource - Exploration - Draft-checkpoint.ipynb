# %% [markdown]
# <img src="http://www.integraconference.info/wp-content/uploads/2017/08/Vendor-Logo-AmerisourceBergen.png" width=60%>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from pylab import rcParams
from pandas.api.types import is_numeric_dtype
from scipy.stats import ttest_ind
# from sklearn.feature_selection import RFE
# from sklearn.linear_model import LogisticRegression
import statsmodels.formula.api as sm

import warnings
warnings.filterwarnings('once')

# %%
# %matplotlib inline
# rcParams['figure.figsize'] = 6, 5
# sb.set_('whitegrid')
sb.set(font='Roboto', style='whitegrid')

# %%
dtype_dic= {'GCNSEQ_NBR':str,'NDC':str}
data = pd.read_csv('dataset_big.csv', header=0, dtype=dtype_dic)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89516 entries, 0 to 89515
# Data columns (total 44 columns):
# ID                          89516 non-null int64
# WK_NBR                      89516 non-null int64
# WK_BEGIN_DTE                89516 non-null object
# WK_END_DTE                  89516 non-null object
# NCPDP_TOKEN                 89516 non-null int64
# PHRMCY_NAME                 89516 non-null object
# BUY_GRP_NAM                 89516 non-null object
# NDC                         89516 non-null object
# NDC_DESC                    89516 non-null object
# BRX_GRX_CD                  89516 non-null object
# NDC_QTY_MTRC                89516 non-null float64
# NDC_PKG_SZ                  89516 non-null float64
# NDC_CASE_PK_QTY             89516 non-null int64
# MFG_NAM                     89516 non-null object
# GCNSEQ_NBR                  89516 non-null object
# GCNSEQ_DESC                 89516 non-null object
# GCNSEQ_RTE_OF_ADMIN_DESC    89516 non-null object
# GCNSEQ_DSG_FORM_CD          89516 non-null object
# GCNSEQ_STR_DESC             89516 non-null object
# DSPN_QTY_NDC_1WK            89516 non-null float64
# DSPN_QTY_NDC_4WKS           89516 non-null float64
# DSPN_QTY_NDC_13WKS          89516 non-null float64
# DSPN_QTY_NDC_26WKS          89516 non-null float64
# DSPN_QTY_GCN_1WK            89516 non-null float64
# DSPN_QTY_GCN_4WKS           89516 non-null float64
# DSPN_QTY_GCN_13WKS          89516 non-null float64
# DSPN_QTY_GCN_26WKS          89516 non-null float64
# PURCH_QTY_NDC_1WK_MTRC      89516 non-null float64
# PURCH_QTY_NDC_4WKS_MTRC     89516 non-null float64
# PURCH_QTY_NDC_13WKS_MTRC    89516 non-null float64
# PURCH_QTY_NDC_26WKS_MTRC    89516 non-null float64
# PURCH_QTY_GCN_1WK_MTRC      89516 non-null float64
# PURCH_QTY_GCN_4WKS_MTRC     89516 non-null float64
# PURCH_QTY_GCN_13WKS_MTRC    89516 non-null float64
# PURCH_QTY_GCN_26WKS_MTRC    89516 non-null float64
# COGS_PRC_MTRC               85770 non-null float64
# DSPN_COGS_NDC_1WK           85770 non-null float64
# DSPN_COGS_NDC_4WKS          89516 non-null float64
# DSPN_COGS_NDC_13WKS         89516 non-null float64
# DSPN_COGS_NDC_26WKS         89516 non-null float64
# DSPN_COGS_GCN_1WK           89516 non-null float64
# DSPN_COGS_GCN_4WKS          89516 non-null float64
# DSPN_COGS_GCN_13WKS         89516 non-null float64
# DSPN_COGS_GCN_26WKS         89516 non-null float64
# dtypes: float64(27), int64(4), object(13)
# memory usage: 30.1+ MB

# %%
# Set up basic functions
# Excluding outliers: +- 3 SDEV
# def removeOutliers(data,field):
#     result = data[np.abs(data[field]-data[field].mean()) <= (3*data[field].std())]
#     return result

# %%
data1 = data[data['PURCH_QTY_NDC_26WKS_MTRC']>0].reset_index().reset_index()
data1 = data1.drop(columns=['index', 'ID'])
data1.rename(columns={'level_0': 'ID'}, inplace=True)
data = data1

# %% [markdown]
# # Create measures for leakage

# %% [markdown]
# ### Clarifying fields/variables
# Even with the help of the accompanying dictionary, it is good to clarify, with reasonable assumptions, what certain fields and columns mean in the context of this dataset.
#
# * MTRC is the unit of measure for each unique NDC.
# * As one can see that  DSPN units can be a real number with decimal points, this is reasonable.
# * DSPN and PURCH are in the same unit.
# * COGS_PRC_MTRC is cost **the pharmacy pays** per unit, so there is no need for conversion.
# * GCN and NDC are seemingly equivalent, but data is grouped by GCN number **for each pharmacy**. Extra caution should be used when handling these fields.
#
# ### Leakage is represented by share of purchase for a type of drug
# * Percentage:
#     - Percentage of (COGS of an NDC bought from AmerisourceBergen) to (COGS of dispensing units)
# * If grouped by any variable, COGS needs to be aggregated before doing an average (avoiding average of averages)
# * Formula: PURCH SALES / DSPN COGS ? **[Percentage will be a ratio for dollars, not quantities]**
# * Columns are named "perc_?"
# * (Tentative) Leakage can be represented as: 1 - Perc

# %%
#Calculate and insert sales for purch
unit_cost = data['COGS_PRC_MTRC']
data.loc[:,'sales_1w'] = Series(data['PURCH_QTY_NDC_1WK_MTRC']*unit_cost, dtype='float32')
data.loc[:,'sales_4w'] = Series(data['PURCH_QTY_NDC_4WKS_MTRC']*unit_cost, dtype='float32')
data.loc[:,'sales_13w'] = Series(data['PURCH_QTY_NDC_13WKS_MTRC']*unit_cost, dtype='float32')
data.loc[:,'sales_26w'] = Series(data['PURCH_QTY_NDC_26WKS_MTRC']*unit_cost, dtype='float32')
data.loc[:,'sales_gcn_1w'] = Series(data['PURCH_QTY_GCN_1WK_MTRC']*unit_cost, dtype='float32')
data.loc[:,'sales_gcn_4w'] = Series(data['PURCH_QTY_GCN_4WKS_MTRC']*unit_cost, dtype='float32')
data.loc[:,'sales_gcn_13w'] = Series(data['PURCH_QTY_GCN_13WKS_MTRC']*unit_cost, dtype='float32')
data.loc[:,'sales_gcn_26w'] = Series(data['PURCH_QTY_GCN_26WKS_MTRC']*unit_cost, dtype='float32')
data.loc[:,'leak_dol_26w'] = Series(data['DSPN_COGS_NDC_26WKS']-data['sales_26w'])

# %%
def getPerc(data):    
    data.loc[:,'perc_1w'] = Series(np.where(data['DSPN_QTY_NDC_1WK'] != 0,data['sales_1w']/data['DSPN_COGS_NDC_1WK'],0), dtype='float32')
    data.loc[:,'perc_4w'] = Series(np.where(data['DSPN_QTY_NDC_4WKS'] != 0,data['sales_4w']/data['DSPN_COGS_NDC_4WKS'],0), dtype='float32')
    data.loc[:,'perc_13w'] = Series(np.where(data['DSPN_QTY_NDC_13WKS'] != 0,data['sales_13w']/data['DSPN_COGS_NDC_13WKS'],0), dtype='float32')
    data.loc[:,'perc_26w'] = Series(np.where(data['DSPN_QTY_NDC_26WKS'] != 0,data['sales_26w']/data['DSPN_COGS_NDC_26WKS'],0), dtype='float32')
    data.loc[:,'leak_26w'] = Series(1 - data['perc_26w'])
def getPercGCN(data):
    data.loc[:,'perc_gcn_1w'] = Series(np.where(data['DSPN_QTY_GCN_1WK'] != 0,data['sales_gcn_1w']/data['DSPN_COGS_GCN_1WK'],0), dtype='float32')
    data.loc[:,'perc_gcn_4w'] = Series(np.where(data['DSPN_QTY_GCN_4WKS'] != 0,data['sales_gcn_4w']/data['DSPN_COGS_GCN_4WKS'],0), dtype='float32')
    data.loc[:,'perc_gcn_13w'] = Series(np.where(data['DSPN_QTY_GCN_13WKS'] != 0,data['sales_gcn_13w']/data['DSPN_COGS_GCN_13WKS'],0), dtype='float32')
    data.loc[:,'perc_gcn_26w'] = Series(np.where(data['DSPN_QTY_GCN_26WKS'] != 0,data['sales_gcn_26w']/data['DSPN_COGS_GCN_26WKS'],0), dtype='float32')

# %% [markdown]
# ### Total Sales Leak

# %%
data.leak_dol_26w.sum()
# Out:
# 870589763.1166912

# %% [markdown]
# # Examine Pharmacies first

# %%
data_bypharm = data.groupby('PHRMCY_NAME').sum().reset_index()

# %%
#now you do the percentages on the dollar amount
getPerc(data_bypharm)

# %%
#remove outliers
data_bypharm_excl = removeOutliers(data_bypharm,'perc_26w')

# %%
#Number of unique pharmacies?
print("Number of unique pharmacies (exl. outliers) is: " + str(len(data_bypharm_excl)))

print("{:.4}% of values remain.".format(len(data_bypharm_excl)/len(data_bypharm)*100))
# Out:
# Number of unique pharmacies (exl. outliers) is: 2697
# 99.89% of values remain.

# %% [markdown]
# # Pharmacies

# %%
data_bypharm.sort_values(by='leak_dol_26w', ascending=False).head(5)
# Out:
#         PHRMCY_NAME         ID     WK_NBR   NCPDP_TOKEN  NDC_QTY_MTRC  \
# 2190   PHARMACY 536   882395.0  9284456.0  1.207971e+20       1747.02
# 872   PHARMACY 1793  2329456.0  8275276.0  2.658589e+20       3720.62
# 1815  PHARMACY 2644   398220.0  1009180.0  4.558175e+19       2066.00
# 1801  PHARMACY 2631  3255359.0  8275276.0  3.719743e+20       1407.52
# 834   PHARMACY 1759  2409419.0  8678948.0  2.736592e+20       1640.10
#
#       NDC_PKG_SZ  NDC_CASE_PK_QTY  DSPN_QTY_NDC_1WK  DSPN_QTY_NDC_4WKS  \
# 2190     1673.58             75.0           4128.62           48358.00
# 872      3635.18             74.0          36357.82           77114.52
# 1815     2066.00              5.0              0.00           29470.00
# 1801     1334.08             70.0          60735.20          248935.82
# 834      1569.60             69.0           1445.20            6469.20
#
#       DSPN_QTY_NDC_13WKS    ...      sales_gcn_1w  sales_gcn_4w  \
# 2190           147624.10    ...     138074.359375  7.068334e+05
# 872            217332.34    ...      48707.394531  1.465304e+05
# 1815           149074.00    ...          0.000000  5.473691e+04
# 1801           786302.96    ...     616591.125000  3.276475e+06
# 834             23141.60    ...      19934.958984  1.580662e+05
#
#       sales_gcn_13w  sales_gcn_26w  leak_dol_26w   perc_1w   perc_4w  \
# 2190   2.021846e+06     4023132.75  4.385465e+08  0.991785  0.007442
# 872    4.666680e+05      832588.00  1.658796e+08  0.000980  0.002140
# 1815   1.127075e+05      134960.00  1.404751e+08  0.000000  0.655544
# 1801   1.034836e+07    14968000.00  1.650589e+07  0.462666  0.556849
# 834    6.539439e+05     1250406.25  1.280310e+07  0.451445  1.124741
#
#       perc_13w  perc_26w  leak_26w
# 2190  0.007479  0.007425  0.992575
# 872   0.003553  0.003832  0.996168
# 1815  0.004494  0.000607  0.999393
# 1801  0.544467  0.394066  0.605934
# 834   0.973641  0.072552  0.927447
#
# [5 rows x 46 columns]

# %% [markdown]
# * Dispensing means "sold to patients". As you can see in the table, due to existing stock, pharmacies naturally buy fewer new drugs in the short term.
# <br> _However, this means that it is difficult to use changes in purchase percentages to evaluate leakage._
# * Some pharmacies bought more than they actually dispensed, but these are in the minority.

# %%
leak_bypharm = data_bypharm[data_bypharm.perc_26w < 0.9]
print("{:.4}% of pharmacies dispensed more than they have bought from AB.".format(len(leak_bypharm)/len(data_bypharm)*100))
print("This means almost all pharmacies leak in some capacity")
# Out:
# 23.04% of pharmacies dispensed more than they have bought from AB.
# This means almost all pharmacies leak in some capacity

# %% [markdown]
# *Consider only those less than or smaller than 1 and larger than 0 (0 suggests no relationship), as pharmacies that overbought should not be a concern*

# %%
#distribution of 26-week percentage of pharmacies that leak
leak_bypharm = data_bypharm_excl[data_bypharm_excl.perc_26w <= 1]
leak_bypharm = leak_bypharm[leak_bypharm.perc_26w >= 0] 

# sb.distplot(leak_bypharm['perc_26w'], kde=True, 
#              bins=20, color = 'green',)
plt.hist(leak_bypharm['perc_26w'], bins = 20)
plt.xlabel("26-week Perc")
plt.ylabel("Number of pharmacies")
leak_bypharm['perc_26w'].describe()
# Out:
# count    1624.000000
# mean        0.846059
# std         0.209876
# min         0.000000
# 25%         0.800623
# 50%         0.937602
# 75%         0.981029
# max         1.000000
# Name: perc_26w, dtype: float64
# c:\users\linhd\appdata\local\programs\python\python36\lib\site-packages\matplotlib\font_manager.py:1238: UserWarning: findfont: Font family ['Roboto'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Group data by NDCs and NDC Descriptions

# %%
data_byNDCdesc = data.groupby('NDC_DESC').sum().reset_index()
getPerc(data_byNDCdesc)

data_byNDC = data.groupby('NDC').sum().reset_index()
getPerc(data_byNDC)

print(data_byNDCdesc.leak_26w.describe())
print('')
print(data_byNDC.leak_26w.describe())
# Out:
# count    62.000000
# mean      0.139008
# std       0.294067
# min      -0.297699
# 25%       0.018846
# 50%       0.065800
# 75%       0.114974
# max       0.999514
# Name: leak_26w, dtype: float64
#
# count    131.000000
# mean       0.035576
# std        0.418075
# min       -1.661602
# 25%       -0.084602
# 50%        0.032253
# 75%        0.101765
# max        1.000000
# Name: leak_26w, dtype: float64

# %% [markdown]
# INSIGHT?: Percs per NDC are smaller -> There are "leaky" NDCs that are not bought even though the whole category is well-bought

# %%
toplot = data_byNDCdesc[(data_byNDCdesc.perc_26w > 0) & (data_byNDCdesc.perc_26w <= 1)]
# toplot2 = data_byNDC[data_byNDC.perc_26w > 0]
# sb.distplot(toplot['perc_26w'], bins=20)
x = pd.Series(toplot['leak_26w'])
plt.figure(figsize=(7.5,2.5))
plt.hist(x, bins=np.linspace(0, 1, 21), histtype='barstacked')
plt.xticks(np.linspace(0, 1, 21), rotation=90)
plt.xlabel("26-week Leak")
plt.ylabel("Frequency of GCNs");

# %%
toplot2 = data_byNDC
# sb.distplot(toplot['perc_26w'], bins=20)
y = toplot2['leak_26w']
plt.figure(figsize=(7.5,2.5))
plt.hist(y, bins=np.linspace(0, 1, 21), histtype='barstacked', color='green')
plt.xticks(np.linspace(0, 1, 21), rotation=90)
plt.xlabel("26-week Leak")
plt.ylabel("Frequency of NDCs");

# %%
data_byNDCdesc.head(3)
# Out:
#                          NDC_DESC       ID    WK_NBR   NCPDP_TOKEN  \
# 0  "ADVATE 1,801-2,400 UNIT VIAL"  19197.0  201836.0  2.626023e+18
# 1     "ADYNOVATE 1,500 UNIT VIAL"  56827.0  201836.0  6.484364e+18
# 2   "HELIXATE FS 1,000 UNIT VIAL"  79644.0  201836.0  9.116349e+18
#
#    NDC_QTY_MTRC  NDC_PKG_SZ  NDC_CASE_PK_QTY  DSPN_QTY_NDC_1WK  \
# 0           1.0         1.0              1.0               0.0
# 1           1.0         1.0              1.0           12104.0
# 2           1.0         1.0              1.0               0.0
#
#    DSPN_QTY_NDC_4WKS  DSPN_QTY_NDC_13WKS    ...     sales_gcn_1w  \
# 0            30525.0             91575.0    ...         0.000000
# 1            12104.0             12104.0    ...     19573.359375
# 2                0.0             14294.0    ...         0.000000
#
#    sales_gcn_4w  sales_gcn_13w  sales_gcn_26w  leak_dol_26w   perc_1w  \
# 0  35528.101562  106584.296875  213168.593750  4.386012e+08  0.000000
# 1  19573.359375   19573.359375   19573.359375  2.959492e+07  0.000661
# 2      0.000000   13545.000000   35797.500000  5.998008e+07  0.000000
#
#     perc_4w  perc_13w  perc_26w  leak_26w
# 0  0.000491  0.000491  0.000486  0.999514
# 1  0.000661  0.000661  0.000661  0.999339
# 2  0.000000  0.000979  0.000596  0.999404
#
# [3 rows x 46 columns]

# %%
toplot = toplot.sort_values(by='leak_26w',ascending=False).reset_index()

plt.figure(figsize=(10,20))
toplot['leak_26w'].plot(kind='barh')
plt.yticks(toplot.index, toplot['NDC_DESC']);
# toplot['NDC_DESC']
# https://stackoverflow.com/questions/20548727/how-to-determine-the-order-of-bars-in-a-matplotlib-bar-chart

# %% [markdown]
# **Chọn mốc cắt theo ý mình**
#
# Sau khi xóa tất cả các PURCH quantity nào mà bằng 0 -> Leak từ 0 -> 40% (Purc percentage khoàng 60-70% chỉ còn có 2 NDC)

# %%
gcnseq_desc = data[['GCNSEQ_DESC','NDC_DESC']].drop_duplicates('NDC_DESC')
new = data_byNDCdesc.merge(gcnseq_desc, on='NDC_DESC',how='left')
new[['NDC_DESC','leak_dol_26w','GCNSEQ_DESC']].to_csv('NDCdesc_byleakdol.csv')

# %% [markdown]
# ## Examining Drug Make-up

# %%
data.loc[:,'GCNSEQ_DESC'] = data['GCNSEQ_DESC'].str.replace('"','')
data.loc[:,'GCNSEQ_DESC'] = data['GCNSEQ_DESC'].str.replace('(3)','')
data.loc[:,'GCNSEQ_DESC'] = data['GCNSEQ_DESC'].str.replace('()','')

# %%
dummies_desc = data['GCNSEQ_DESC'].str.get_dummies(sep=' ')

# %%
dummies_desc = dummies_desc.reset_index()
dummies_desc.rename(columns={'index': 'ID'}, inplace=True);

# %%
dummies_brand = data['GCNSEQ_DESC'].str.get_dummies(sep=' ')

# %%
data_merged = data.merge(dummies_desc,on='ID', how='left');

# %% [markdown]
# ### Leakage with dummy variables

# %%
data_count = data_merged.iloc[:,5:193]
data_count['cogs_26w'] = data_merged['DSPN_COGS_NDC_26WKS']
data_count['sales_26w'] = data_merged['sales_26w']
data_count['price'] = data_merged['COGS_PRC_MTRC']

# %%
data_count.to_csv('data_spss.csv')

# %%
getPerc(data_count)

# %%
data_count
# Out:
#          PHRMCY_NAME BUY_GRP_NAM          NDC                        NDC_DESC  \
# 0      PHARMACY 1448    CLIPPERS  00071101468            LYRICA 75 MG CAPSULE
# 1      PHARMACY 1448    CLIPPERS  00173069600            ADVAIR 250-50 DISKUS
# 2      PHARMACY 1448    CLIPPERS  12496120803      SUBOXONE 8 MG-2 MG SL FILM
# 3      PHARMACY 1448    CLIPPERS  00002751001       HUMALOG 100 UNITS/ML VIAL
# 4      PHARMACY 1448    CLIPPERS  00074433902         HUMIRA 40 MG/0.8 ML PEN
# 5      PHARMACY 1448    CLIPPERS  00597007541    SPIRIVA 18 MCG CP-HANDIHALER
# 6      PHARMACY 1448    CLIPPERS  00071101668           LYRICA 150 MG CAPSULE
# 7      PHARMACY 1448    CLIPPERS  42858010450  OXYCODONE-ACETAMINOPHEN 10-325
# 8      PHARMACY 1448    CLIPPERS  00169406013    VICTOZA 3-PAK 18 MG/3 ML PEN
# 9      PHARMACY 1448    CLIPPERS  00186037020   SYMBICORT 160-4.5 MCG INHALER
# 10     PHARMACY 1448    CLIPPERS  00006027754           JANUVIA 100 MG TABLET
# 11     PHARMACY 1448    CLIPPERS  60951071270        ENDOCET 10-325 MG TABLET
# 12     PHARMACY 1448    CLIPPERS  53746020405  OXYCODONE-ACETAMINOPHEN 10-325
# 13     PHARMACY 1448    CLIPPERS  00088222033         LANTUS 100 UNIT/ML VIAL
# 14     PHARMACY 1448    CLIPPERS  59310057922       PROAIR HFA 90 MCG INHALER
# 15     PHARMACY 1448    CLIPPERS  00003089421             ELIQUIS 5 MG TABLET
# 16     PHARMACY 1448    CLIPPERS  00597014090           TRADJENTA 5 MG TABLET
# 17     PHARMACY 1448    CLIPPERS  00169750111        NOVOLOG 100 UNIT/ML VIAL
# 18     PHARMACY 1448    CLIPPERS  00006027731           JANUVIA 100 MG TABLET
# 19     PHARMACY 1448    CLIPPERS  00002143480     TRULICITY 1.5 MG/0.5 ML PEN
# 20     PHARMACY 1448    CLIPPERS  61958200201        DESCOVY 200-25 MG TABLET
# 21     PHARMACY 1448    CLIPPERS  65162041503  BUPRENORPHIN-NALOXON 8-2 MG SL
# 22     PHARMACY 1448    CLIPPERS  00173068220     VENTOLIN HFA 90 MCG INHALER
# 23     PHARMACY 1448    CLIPPERS  00169643810  LEVEMIR FLEXTOUCH 100 UNITS/ML
# 24     PHARMACY 1448    CLIPPERS  00169633910    NOVOLOG 100 UNITS/ML FLEXPEN
# 25     PHARMACY 1448    CLIPPERS  00054018913  BUPRENORPHIN-NALOXON 8-2 MG SL
# 26     PHARMACY 1448    CLIPPERS  00002879959    HUMALOG 100 UNITS/ML KWIKPEN
# 27     PHARMACY 1448    CLIPPERS  00591261205  HYDROCODONE-ACETAMIN 10-325 MG
# 28     PHARMACY 1448    CLIPPERS  00088221905     LANTUS SOLOSTAR 100 UNIT/ML
# 29     PHARMACY 1448    CLIPPERS  00023916360     RESTASIS 0.05% EYE EMULSION
# ...              ...         ...          ...                             ...
# 80642  PHARMACY 2679   CAVALIERS  00088221905     LANTUS SOLOSTAR 100 UNIT/ML
# 80643  PHARMACY 2679   CAVALIERS  00169406012    VICTOZA 2-PAK 18 MG/3 ML PEN
# 80644  PHARMACY 2679   CAVALIERS  00023916360     RESTASIS 0.05% EYE EMULSION
# 80645  PHARMACY 2679   CAVALIERS  00003089470             ELIQUIS 5 MG TABLET
# 80646  PHARMACY 2679   CAVALIERS  00169406013    VICTOZA 3-PAK 18 MG/3 ML PEN
# 80647  PHARMACY 2679   CAVALIERS  00002771559    BASAGLAR 100 UNIT/ML KWIKPEN
# 80648  PHARMACY 2679   CAVALIERS  50458057930            XARELTO 20 MG TABLET
# 80649  PHARMACY 2679   CAVALIERS  00597014030           TRADJENTA 5 MG TABLET
# 80650  PHARMACY 2679   CAVALIERS  00186037020   SYMBICORT 160-4.5 MCG INHALER
# 80651  PHARMACY 2679   CAVALIERS  00071101468            LYRICA 75 MG CAPSULE
# 80652  PHARMACY 2679   CAVALIERS  00173069600            ADVAIR 250-50 DISKUS
# 80653  PHARMACY 2679   CAVALIERS  12496120803      SUBOXONE 8 MG-2 MG SL FILM
# 80654  PHARMACY 2679   CAVALIERS  00024592410        ADMELOG 100 UNIT/ML VIAL
# 80655  PHARMACY 2679   CAVALIERS  00002751001       HUMALOG 100 UNITS/ML VIAL
# 80656  PHARMACY 2679   CAVALIERS  00406012510  HYDROCODONE-ACETAMIN 10-325 MG
# 80657  PHARMACY 2679   CAVALIERS  00074433902         HUMIRA 40 MG/0.8 ML PEN
# 80658  PHARMACY 2679   CAVALIERS  00597007541    SPIRIVA 18 MCG CP-HANDIHALER
# 80659  PHARMACY 2679   CAVALIERS  00071101668           LYRICA 150 MG CAPSULE
# 80660  PHARMACY 2679   CAVALIERS  60951071270        ENDOCET 10-325 MG TABLET
# 80661  PHARMACY 2679   CAVALIERS  53746020405  OXYCODONE-ACETAMINOPHEN 10-325
# 80662  PHARMACY 2679   CAVALIERS  00006027754           JANUVIA 100 MG TABLET
# 80663  PHARMACY 2679   CAVALIERS  59310057922       PROAIR HFA 90 MCG INHALER
# 80664  PHARMACY 2679   CAVALIERS  00003089421             ELIQUIS 5 MG TABLET
# 80665  PHARMACY 2679   CAVALIERS  00169750111        NOVOLOG 100 UNIT/ML VIAL
# 80666  PHARMACY 2679   CAVALIERS  00002143480     TRULICITY 1.5 MG/0.5 ML PEN
# 80667  PHARMACY 2679   CAVALIERS  00024592505    ADMELOG SOLOSTAR 100 UNIT/ML
# 80668  PHARMACY 2679   CAVALIERS  00173068220     VENTOLIN HFA 90 MCG INHALER
# 80669  PHARMACY 2679   CAVALIERS  00169643810  LEVEMIR FLEXTOUCH 100 UNITS/ML
# 80670  PHARMACY 2679   CAVALIERS  58406044504   ENBREL 50 MG/ML SURECLICK SYR
# 80671  PHARMACY 2679   CAVALIERS  00169633910    NOVOLOG 100 UNITS/ML FLEXPEN
#
#       BRX_GRX_CD  NDC_QTY_MTRC  NDC_PKG_SZ  NDC_CASE_PK_QTY          MFG_NAM  \
# 0            BRX         90.00       90.00                1  PFIZER US PHARM
# 1            BRX         60.00       60.00                1  GLAXOSMITHKLINE
# 2            BRX         30.00       30.00                1    INDIVIOR INC.
# 3            BRX         10.00       10.00                1  ELI LILLY & CO.
# 4            BRX          2.00        2.00                1    ABBVIE US LLC
# 5            BRX         30.00       30.00                1  BOEHRINGER ING.
# 6            BRX         90.00       90.00                1  PFIZER US PHARM
# 7            GRX        500.00      500.00                1  RHODES PHARMACE
# 8            BRX          9.00        3.00                3     NOVO NORDISK
# 9            BRX         10.20       10.20                1      ASTRAZENECA
# 10           BRX         90.00       90.00                1  MERCK SHARP & D
# 11           GRX        100.00      100.00                1  QUALITEST/PAR P
# 12           GRX        500.00      500.00                1  AMNEAL PHARMACE
# 13           BRX         10.00       10.00                1   SANOFI-AVENTIS
# 14           BRX          8.50        8.50                1   TEVA SPECIALTY
# 15           BRX         60.00       60.00                1  BMS PRIMARYCARE
# 16           BRX         90.00       90.00                1  BOEHRINGER ING.
# 17           BRX         10.00       10.00                1     NOVO NORDISK
# 18           BRX         30.00       30.00                1  MERCK SHARP & D
# 19           BRX          2.00        0.50                4  ELI LILLY & CO.
# 20           BRX         30.00       30.00                1  GILEAD SCIENCES
# 21           GRX         30.00       30.00                1  AMNEAL PHARMACE
# 22           BRX         18.00       18.00                1  GLAXOSMITHKLINE
# 23           BRX         15.00        3.00                5     NOVO NORDISK
# 24           BRX         15.00        3.00                5     NOVO NORDISK
# 25           GRX         30.00       30.00                1  WEST-WARD/HIKMA
# 26           BRX         15.00        3.00                5  ELI LILLY & CO.
# 27           GRX        500.00      500.00                1  ACTAVIS PHARMA/
# 28           BRX         15.00        3.00                5   SANOFI-AVENTIS
# 29           BRX         60.00       60.00                1    ALLERGAN INC.
# ...          ...           ...         ...              ...              ...
# 80642        BRX         15.00        3.00                5   SANOFI-AVENTIS
# 80643        BRX          6.00        3.00                2     NOVO NORDISK
# 80644        BRX         60.00       60.00                1    ALLERGAN INC.
# 80645        BRX         74.00       74.00                1  BMS PRIMARYCARE
# 80646        BRX          9.00        3.00                3     NOVO NORDISK
# 80647        BRX         15.00        3.00                5  ELI LILLY & CO.
# 80648        BRX         30.00       30.00                1   JANSSEN PHARM.
# 80649        BRX         30.00       30.00                1  BOEHRINGER ING.
# 80650        BRX         10.20       10.20                1      ASTRAZENECA
# 80651        BRX         90.00       90.00                1  PFIZER US PHARM
# 80652        BRX         60.00       60.00                1  GLAXOSMITHKLINE
# 80653        BRX         30.00       30.00                1    INDIVIOR INC.
# 80654        BRX         10.00       10.00                1   SANOFI-AVENTIS
# 80655        BRX         10.00       10.00                1  ELI LILLY & CO.
# 80656        GRX       1000.00     1000.00                1  MALLINCKRODT PH
# 80657        BRX          2.00        2.00                1    ABBVIE US LLC
# 80658        BRX         30.00       30.00                1  BOEHRINGER ING.
# 80659        BRX         90.00       90.00                1  PFIZER US PHARM
# 80660        GRX        100.00      100.00                1  QUALITEST/PAR P
# 80661        GRX        500.00      500.00                1  AMNEAL PHARMACE
# 80662        BRX         90.00       90.00                1  MERCK SHARP & D
# 80663        BRX          8.50        8.50                1   TEVA SPECIALTY
# 80664        BRX         60.00       60.00                1  BMS PRIMARYCARE
# 80665        BRX         10.00       10.00                1     NOVO NORDISK
# 80666        BRX          2.00        0.50                4  ELI LILLY & CO.
# 80667        BRX         15.00        3.00                5   SANOFI-AVENTIS
# 80668        BRX         18.00       18.00                1  GLAXOSMITHKLINE
# 80669        BRX         15.00        3.00                5     NOVO NORDISK
# 80670        BRX          3.92        0.98                4            AMGEN
# 80671        BRX         15.00        3.00                5     NOVO NORDISK
#
#       GCNSEQ_NBR      ...      sofosbuvir/velpatasvir sulfate tiotropium  \
# 0          57801      ...                           0       0          0
# 1          43367      ...                           0       0          0
# 2          66636      ...                           0       0          0
# 3          27413      ...                           0       0          0
# 4          61205      ...                           0       0          0
# 5          50714      ...                           0       0          1
# 6          57803      ...                           0       0          0
# 7          48977      ...                           0       0          0
# 8          65344      ...                           0       0          0
# 9          62726      ...                           0       0          0
# 10         61614      ...                           0       0          0
# 11         48977      ...                           0       0          0
# 12         48977      ...                           0       0          0
# 13         47780      ...                           0       0          0
# 14         28090      ...                           0       1          0
# 15         70414      ...                           0       0          0
# 16         67353      ...                           0       0          0
# 17         44340      ...                           0       0          0
# 18         61614      ...                           0       0          0
# 19         72873      ...                           0       0          0
# 20         75812      ...                           0       0          0
# 21         51641      ...                           0       0          0
# 22         28090      ...                           0       1          0
# 23         57439      ...                           0       0          0
# 24         44341      ...                           0       0          0
# 25         51641      ...                           0       0          0
# 26         34731      ...                           0       0          0
# 27         30623      ...                           0       0          0
# 28         62867      ...                           0       0          0
# 29         51820      ...                           0       0          0
# ...          ...      ...                         ...     ...        ...
# 80642      62867      ...                           0       0          0
# 80643      65344      ...                           0       0          0
# 80644      51820      ...                           0       0          0
# 80645      70414      ...                           0       0          0
# 80646      65344      ...                           0       0          0
# 80647      62867      ...                           0       0          0
# 80648      68119      ...                           0       0          0
# 80649      67353      ...                           0       0          0
# 80650      62726      ...                           0       0          0
# 80651      57801      ...                           0       0          0
# 80652      43367      ...                           0       0          0
# 80653      66636      ...                           0       0          0
# 80654      27413      ...                           0       0          0
# 80655      27413      ...                           0       0          0
# 80656      30623      ...                           0       0          0
# 80657      61205      ...                           0       0          0
# 80658      50714      ...                           0       0          1
# 80659      57803      ...                           0       0          0
# 80660      48977      ...                           0       0          0
# 80661      48977      ...                           0       0          0
# 80662      61614      ...                           0       0          0
# 80663      28090      ...                           0       1          0
# 80664      70414      ...                           0       0          0
# 80665      44340      ...                           0       0          0
# 80666      72873      ...                           0       0          0
# 80667      34731      ...                           0       0          0
# 80668      28090      ...                           0       1          0
# 80669      57439      ...                           0       0          0
# 80670      61938      ...                           0       0          0
# 80671      44341      ...                           0       0          0
#
#          cogs_26w      price   perc_1w   perc_4w  perc_13w  perc_26w  \
# 0      10895.6799     7.1158  0.000000  0.000000  1.302088  0.999219
# 1      10184.1300     6.2865  0.000000  2.250000  1.000000  0.962963
# 2      64062.2220     7.8020  2.634146  1.229508  1.111111  1.048593
# 3       6577.7500    26.3110  0.000000  1.000000  1.000000  1.080000
# 4      38196.7200  2387.2950  0.000000  2.000000  1.000000  0.875000
# 5       6853.6800    12.6920  0.000000  1.000000  0.875000  0.944444
# 6      10848.7108     7.1158  0.000000  1.285718  0.862692  0.944513
# 7          0.0000        NaN  0.000000  0.000000  0.000000  0.000000
# 8      20170.1701    92.6289  1.000000  1.166667  0.946158  0.991952
# 9      16604.9000    30.7157  1.000000  1.500001  1.000000  0.943397
# 10      8226.8640    13.7114  0.000000  0.000000  0.374999  0.749998
# 11       965.8800     1.0732  0.000000  1.333333  0.444444  1.000000
# 12      1934.5593     0.3946  2.083333  1.096491  1.003604  1.223845
# 13      4569.0600    25.8170  0.000000  0.000000  1.000000  0.904063
# 14      8384.8800     6.7106  0.333334  1.086958  1.046156  0.986396
# 15     33703.3368     6.6872  3.500016  0.900004  1.000004  1.000005
# 16      5515.9062    13.1331  0.000000  2.999998  1.666665  1.499999
# 17      9410.0700    27.7150  0.000000  0.923077  1.066213  1.089742
# 18         0.0000        NaN  0.000000  0.000000  0.000000  0.000000
# 19     15282.7600   349.6950  0.000000  0.666667  1.000000  0.915267
# 20      1642.2740    54.7425  0.000000  0.000000  1.000001  1.000001
# 21      1001.3186     3.4297  0.000000  0.000000  0.000000  0.616533
# 22      8132.2447     2.8594  1.285697  0.952368  0.970136  0.980999
# 23     10856.9916    28.7873  0.999999  1.333332  1.175367  1.073857
# 24     13024.5309    35.6833  0.999999  2.333331  1.154634  0.986292
# 25      1464.4693     3.4297  0.000000  1.312511  0.913357  1.264648
# 26      8128.3200    33.8680  0.000000  1.333333  0.800000  0.812500
# 27       443.8766     0.1959  0.000000  0.895875  1.123709  1.103347
# 28     25284.3183    25.8153  2.499997  0.777777  0.999999  0.995475
# 29      8290.7334     8.1282  1.000004  1.000004  0.833336  0.941180
# ...           ...        ...       ...       ...       ...       ...
# 80642  15090.9390    25.8153  0.000000  1.410255  1.144066  1.129028
# 80643   2101.0500    92.6300  0.000000  2.075994  1.752188  1.587149
# 80644  13130.8074     8.1153  0.000000  0.799997  0.666664  0.815806
# 80645      0.0000        NaN  0.000000  0.000000  0.000000  0.000000
# 80646  18267.4403    93.5967  0.502599  1.678236  0.799126  1.014491
# 80647  22656.5520    21.2140  1.000000  0.846154  1.063218  1.109551
# 80648  21355.8852    13.6897  4.000009  1.500003  1.120002  1.096156
# 80649   4711.3107    13.1127  0.000000  0.000000  0.200000  0.751474
# 80650  16865.2800    30.6677  1.200002  0.800001  0.961540  0.964475
# 80651   6898.5854     7.3888  0.000000  0.000000  0.640656  0.867559
# 80652   7143.0138     6.2767  3.000014  1.000005  0.750004  0.949016
# 80653   2628.8014     7.7897  0.000000  1.071433  1.235299  0.977861
# 80654      0.0000        NaN  0.000000  0.000000  0.000000  0.000000
# 80655  18428.7000    26.5860  2.500000  1.189649  0.941776  0.952143
# 80656    539.1082     0.1065  0.000000  0.952560  0.809869  0.790194
# 80657  28647.5400  2387.2950  0.000000  1.000000  1.000000  1.000000
# 80658   7962.0903    12.6723  0.000000  0.000000  0.800375  0.668463
# 80659   6421.2717     7.3888  0.000000  0.000000  1.030831  1.035608
# 80660    160.9800     1.0732  0.000000  0.000000  0.000000  0.666667
# 80661    431.9792     0.3788  0.000000  0.000000  0.000000  1.315341
# 80662  18865.1352    13.6900  0.600000  1.200000  1.080000  1.044975
# 80663   1250.8200     6.7000  0.000000  0.750000  0.818182  0.637422
# 80664  24455.0606     6.6767  0.000000  1.200005  0.936285  1.032012
# 80665  15454.7700    27.7150  0.000000  0.909091  1.237294  1.129777
# 80666  11889.6300   349.6950  0.000000  0.500000  0.888889  0.941176
# 80667   2418.1920    28.7880  0.000000  0.750000  1.428571  1.428571
# 80668  16991.1378     2.8550  1.866667  0.983051  1.005814  1.001115
# 80669   6415.4906    28.7873  0.999999  0.357142  0.984372  1.009610
# 80670  28647.3600  1218.0000  0.000000  1.000000  1.000000  1.000000
# 80671  28908.8686    35.6833  0.000000  0.510204  0.891004  0.907238
#
#            leak_26w
# 0      7.807016e-04
# 1      3.703701e-02
# 2     -4.859328e-02
# 3     -8.000004e-02
# 4      1.250000e-01
# 5      5.555558e-02
# 6      5.548668e-02
# 7      1.000000e+00
# 8      8.047938e-03
# 9      5.660337e-02
# 10     2.500022e-01
# 11     0.000000e+00
# 12    -2.238446e-01
# 13     9.593654e-02
# 14     1.360375e-02
# 15    -4.529953e-06
# 16    -4.999988e-01
# 17    -8.974218e-02
# 18     1.000000e+00
# 19     8.473343e-02
# 20    -5.960464e-07
# 21     3.834670e-01
# 22     1.900071e-02
# 23    -7.385695e-02
# 24     1.370817e-02
# 25    -2.646478e-01
# 26     1.875000e-01
# 27    -1.033472e-01
# 28     4.524529e-03
# 29     5.882007e-02
# ...             ...
# 80642 -1.290283e-01
# 80643 -5.871493e-01
# 80644  1.841936e-01
# 80645  1.000000e+00
# 80646 -1.449060e-02
# 80647 -1.095506e-01
# 80648 -9.615624e-02
# 80649  2.485257e-01
# 80650  3.552455e-02
# 80651  1.324412e-01
# 80652  5.098379e-02
# 80653  2.213949e-02
# 80654  1.000000e+00
# 80655  4.785687e-02
# 80656  2.098061e-01
# 80657  5.960464e-08
# 80658  3.315366e-01
# 80659 -3.560793e-02
# 80660  3.333333e-01
# 80661 -3.153411e-01
# 80662 -4.497528e-02
# 80663  3.625782e-01
# 80664 -3.201234e-02
# 80665 -1.297773e-01
# 80666  5.882353e-02
# 80667 -4.285715e-01
# 80668 -1.115441e-03
# 80669 -9.609818e-03
# 80670  0.000000e+00
# 80671  9.276199e-02
#
# [80672 rows x 193 columns]

# %%
data_count['cogs_26w'];

# %%
d = {}
for i in data_count:
    if i not in ['cogs_26w','sales_26w','price']:
        cogs = data_count[data_count[i] == 1]['cogs_26w'].sum()
        sales = data_count[data_count[i] == 1]['sales_26w'].sum()
        d[i] = 1 - sales/cogs
# Out:
# c:\users\linhd\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in true_divide

# %%
leak_by_ingr = pd.DataFrame.from_dict(d, orient='index',columns=['leak_26w']).reset_index()

# %%
leak_by_ingr.sort_values(by='index', ascending=False).to_csv('leak_by_ingr.csv')

# %%
# leak_by_ingr.head(10)

# %%
k = {}
for i in data_count:
    if i not in ['cogs_26w','sales_26w','price']:
        k[i] = data_count[data_count[i] == 1]['price'].mean()

# %%
price_by_ingr = pd.DataFrame.from_dict(k, orient='index',columns=['av_price']).reset_index()

# %%
price_by_ingr.sort_values(by='index', ascending=False).to_csv('leak_by_price.csv')

# %%
h = {}
for i in data_count:
    if i not in ['cogs_26w','sales_26w','price']:
        h[i] = data_count[data_count[i] == 1]['cogs_26w'].sum()

# %%
cogs_by_ingr = pd.DataFrame.from_dict(h, orient='index',columns=['cogs_26w']).reset_index()

# %%
cogs_by_ingr.sort_values(by='index', ascending=False).to_csv('cogs_by_ingr.csv')

# %%
j = {}
for i in data_count:
    if i not in ['cogs_26w','sales_26w','price']:
        j[i] = data_count[data_count[i] == 1]['sales_26w'].sum()

# %%
sales_by_ingr = pd.DataFrame.from_dict(j, orient='index',columns=['sales_26w']).reset_index()

# %%
sales_by_ingr.sort_values(by='index', ascending=False).to_csv('sales_by_ingr.csv')

# %%
leak_by_ingr = leak_by_ingr.merge(price_by_ingr, on='index',how='left')
leak_by_ingr = leak_by_ingr.merge(cogs_by_ingr, on='index',how='left')
leak_by_ingr = leak_by_ingr.merge(sales_by_ingr, on='index',how='left')

# %%
leak_by_ingr.sort_values(by='index', ascending=False).to_csv('leak_ingr_summary.csv')

# %% [markdown]
# ## _Three top leakers are different NDCs with a shared ingredients_

# %%
getPerc(data_merged)
# data_merged = data_merged[data_merged.perc_26w < 1]

# %%
data_merged[data_merged['emtricitab/rilpiviri/tenof'] == 1][['PHRMCY_NAME','NDC_DESC','GCNSEQ_DESC','perc_13w','perc_26w']].head(8)
#Maybe different NDC leads to
# Out:
#         PHRMCY_NAME        NDC_DESC  \
# 891    PHARMACY 117  ODEFSEY TABLET
# 1427   PHARMACY 365  ODEFSEY TABLET
# 2428   PHARMACY 707  ODEFSEY TABLET
# 2499   PHARMACY 710  ODEFSEY TABLET
# 3130   PHARMACY 873  ODEFSEY TABLET
# 3246   PHARMACY 905  ODEFSEY TABLET
# 3751  PHARMACY 1107  ODEFSEY TABLET
# 4698     PHARMACY 2  ODEFSEY TABLET
#
#                                             GCNSEQ_DESC  perc_13w  perc_26w
# 891   emtricitab/rilpiviri/tenof ala ORAL TABLET 200...  1.000000  1.000000
# 1427  emtricitab/rilpiviri/tenof ala ORAL TABLET 200...  0.666666  0.909091
# 2428  emtricitab/rilpiviri/tenof ala ORAL TABLET 200...  0.000000  0.031504
# 2499  emtricitab/rilpiviri/tenof ala ORAL TABLET 200...  1.000000  1.000000
# 3130  emtricitab/rilpiviri/tenof ala ORAL TABLET 200...  0.545454  0.518518
# 3246  emtricitab/rilpiviri/tenof ala ORAL TABLET 200...  0.519481  0.521127
# 3751  emtricitab/rilpiviri/tenof ala ORAL TABLET 200...  1.000000  1.000000
# 4698  emtricitab/rilpiviri/tenof ala ORAL TABLET 200...  1.000000  1.000000

# %%
data_merged[data_merged['bictegrav/emtricit/tenofov'] == 1][['PHRMCY_NAME','NDC_DESC','GCNSEQ_DESC','perc_13w','perc_26w']].head(6)
# Out:
#        PHRMCY_NAME                      NDC_DESC  \
# 863    PHARMACY 82  BIKTARVY 50-200-25 MG TABLET
# 888   PHARMACY 117  BIKTARVY 50-200-25 MG TABLET
# 1370  PHARMACY 350  BIKTARVY 50-200-25 MG TABLET
# 1422  PHARMACY 365  BIKTARVY 50-200-25 MG TABLET
# 1487  PHARMACY 375  BIKTARVY 50-200-25 MG TABLET
# 1512  PHARMACY 389  BIKTARVY 50-200-25 MG TABLET
#
#                                             GCNSEQ_DESC  perc_13w  perc_26w
# 863   bictegrav/emtricit/tenofov ala ORAL TABLET 50-...  0.427319  0.332198
# 888   bictegrav/emtricit/tenofov ala ORAL TABLET 50-...  1.000000  1.000000
# 1370  bictegrav/emtricit/tenofov ala ORAL TABLET 50-...  1.000000  0.998976
# 1422  bictegrav/emtricit/tenofov ala ORAL TABLET 50-...  0.994395  0.987998
# 1487  bictegrav/emtricit/tenofov ala ORAL TABLET 50-...  1.000000  1.000000
# 1512  bictegrav/emtricit/tenofov ala ORAL TABLET 50-...  0.988910  0.988910

# %%
data_merged[data_merged['alafen'] == 1][['PHRMCY_NAME','NDC_DESC','GCNSEQ_DESC','perc_13w','perc_26w']].head(7)
# Out:
#        PHRMCY_NAME        NDC_DESC  \
# 81    PHARMACY 165  GENVOYA TABLET
# 102   PHARMACY 319  GENVOYA TABLET
# 133   PHARMACY 430  GENVOYA TABLET
# 300   PHARMACY 765  GENVOYA TABLET
# 759    PHARMACY 73  GENVOYA TABLET
# 871    PHARMACY 82  GENVOYA TABLET
# 1004  PHARMACY 199  GENVOYA TABLET
#
#                                             GCNSEQ_DESC  perc_13w  perc_26w
# 81    elviteg/cob/emtri/tenof alafen ORAL TABLET 150...  1.000000  1.000000
# 102   elviteg/cob/emtri/tenof alafen ORAL TABLET 150...  0.750000  1.000001
# 133   elviteg/cob/emtri/tenof alafen ORAL TABLET 150...  1.331059  1.331059
# 300   elviteg/cob/emtri/tenof alafen ORAL TABLET 150...  1.000000  1.000000
# 759   elviteg/cob/emtri/tenof alafen ORAL TABLET 150...  1.000000  0.997443
# 871   elviteg/cob/emtri/tenof alafen ORAL TABLET 150...  0.403753  0.271369
# 1004  elviteg/cob/emtri/tenof alafen ORAL TABLET 150...  1.000000  1.090909

# %% [markdown]
# A story here. Tenofovi Alafenamide is a new HIV drug, but seems to be marketed under different NDC (names), with slightly different mixture of ingredients.
# * Perhaps the differences confuse pharmacies
# * For DESCOVY and GENVOYA, pharmacies seem to underbuy (in comparision to dispense) in the long-term, then in a shorter timeframe tries to close this gap. Trust or more consumer may have helped reduce leakage.

# %% [markdown]
# # Searching for patterns

# %% [markdown]
# ## 1. Price per pharmacy, Purchase Percentage, and Manufacturer

# %% [markdown]
# **Hypothesis:** if an NDC is more expensive than the category average, they should exhibit higher leakage

# %%
#initial dataframe to determine aver.cost per NDC
data_mean_cost_per_NDC = data[['NDC','COGS_PRC_MTRC']].groupby('NDC').mean().reset_index()
#prep by re-introducing the 'MFG_NAM' column.
mfg_name = data[['MFG_NAM','NDC']].drop_duplicates('NDC')
#prep by re-introducing the 'NDC_DESC' column.
ndc_desc = data[['NDC_DESC','NDC']].drop_duplicates('NDC')
#merge 
scat_data = data_mean_cost_per_NDC.merge(mfg_name,on='NDC', how='left')
scat_data = scat_data.merge(ndc_desc,on='NDC', how='left')

# %%
#prep by calculating a "price index" from -1 to 1, representing deviation from the average price of the GNC
gnc_num = data[['GCNSEQ_NBR','NDC']].drop_duplicates('NDC')
gnc_av_price = data[['GCNSEQ_NBR','NDC','COGS_PRC_MTRC']].groupby(['GCNSEQ_NBR']).mean().reset_index()
gnc_av_price = gnc_av_price.rename(index=str, columns={"COGS_PRC_MTRC": "average_price"})

# %%
#prep by branded and generics
gen = data[['BRX_GRX_CD','NDC']].drop_duplicates('NDC')

# %%
#prep by buying groups
buy = data[['NDC','BUY_GRP_NAM']].drop_duplicates('NDC')

# %%
#joining columns 
scat_data = scat_data.merge(gnc_num,on='NDC', how='left')
scat_data = scat_data.merge(gnc_av_price,on='GCNSEQ_NBR', how='left')
scat_data = scat_data.merge(data_byNDC[['NDC','leak_26w']],on='NDC',how='left')
scat_data = scat_data.merge(data_byNDC[['NDC','leak_dol_26w']],on='NDC',how='left')
scat_data = scat_data.merge(gen,on='NDC', how='left')
scat_data = scat_data.merge(buy,on='NDC', how='left')

# %%
scat_data.loc[:,'price_index'] = Series((scat_data.COGS_PRC_MTRC - scat_data.average_price)/scat_data.average_price)

# %%
check = scat_data[['NDC','COGS_PRC_MTRC','BRX_GRX_CD','average_price','price_index','leak_26w']]
check[check.price_index > 1].head(4)
#exorbitant price compared to that of other NDCs in the same GCN
# Out:
#             NDC  COGS_PRC_MTRC BRX_GRX_CD  average_price  price_index  \
# 12  00023602201       4.568753        BRX       0.213863    20.363016
# 13  00023602205       4.326175        BRX       0.213863    19.228748
# 56  00406012562       0.555900        GRX       0.213863     1.599331
# 74  00944304510    2368.540000        BRX     701.236650     2.377661
#
#     leak_26w
# 12 -0.354401
# 13 -0.218302
# 56 -0.190476
# 74  0.999514

# %%
#Advanced: use the actual GCN price -> Later
# gnc_av_price = data[['GCNSEQ_NBR','NDC','PHRMCY_NAME','COGS_PRC_MTRC']].groupby(['PHRMCY_NAME','GCNSEQ_NBR'])

# %%
#try to limit it between 0 and 1 (0 to 100%)
# scat_data = scat_data[(scat_data.leak_26w > 0 )]
scat_data = scat_data[scat_data.price_index < 0.75]

# %%
removeOutliers(scat_data,'price_index').sort_values(by='leak_26w').head(20);
scat_data = scat_data[scat_data.leak_26w < 0.8];

# %% [markdown]
# ### Unit Price and Leakage
# Based on the hypothesize that pharmacies are less loyal when it comes to costlier drug

# %%
plt.figure(figsize=(9,9))
g = sb.scatterplot(x='leak_26w', y='price_index', data=scat_data,hue="BRX_GRX_CD",size='leak_dol_26w', sizes = (150,500),legend=False)
# plt.setp(g.get_legend().get_texts(), fontsize='12')
plt.xlabel("Leakage Rate")
plt.ylabel("Price Index")
plt.savefig("price_index.png", transparent=True)

# %% [markdown]
# No relationship

# %%
data_grx_scat = scat_data[scat_data['BRX_GRX_CD'] == 'GRX']
data_brx_scat = scat_data[scat_data['BRX_GRX_CD'] == 'BRX']

# %%
plt.figure(figsize=(7,7))
l = sb.scatterplot(x='leak_26w', y='price_index', data=data_grx_scat, size='leak_dol_26w', sizes = (70,400))
# plt.setp(g.get_legend().get_texts(), fontsize='12')
# plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel("Leakage Rate")
plt.ylabel("Price Index")
# , size='leak_dol_26w'
# Out:
# Text(0, 0.5, 'Price Index')

# %%
plt.figure(figsize=(7,7))
l = sb.scatterplot(x='leak_26w', y='price_index', data=data_brx_scat, size='leak_dol_26w', sizes = (70,400))
# plt.setp(g.get_legend().get_texts(), fontsize='12')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel("Leakage Rate")
plt.ylabel("Price Index")
# , size='leak_dol_26w'
# Out:
# Text(0, 0.5, 'Price Index')

# %% [markdown]
# ## 2. Branded and Generic NDCs

# %% [markdown]
# ### With Price at NDC level

# %%
# def removeOutliers(data,field):
#     result = data[np.abs(data[field]-data[field].mean()) <= (3*data[field].std())]
#     return result
brand = data[['NDC','BRX_GRX_CD']].drop_duplicates('NDC')
buy_group = data[['NDC','BUY_GRP_NAM']].drop_duplicates('NDC')
data_brand = data_byNDC.merge(brand,on='NDC', how='left')
data_brand = data_brand.merge(buy_group,on='NDC', how='left')

# %%
data_brand = removeOutliers(data_brand,'leak_dol_26w')
data_brand = data_brand[data_brand['leak_26w'] > 0]

# %%
# data_brand = data_brand[data_brand['leak_26w'] < 0.9]
data_brand = data_brand[data_brand['COGS_PRC_MTRC'] < 60000]

# %%
branded = data_brand[data_brand.BRX_GRX_CD == 'BRX']
generic = data_brand[data_brand.BRX_GRX_CD == 'GRX']

x = branded['perc_26w']
y = generic['perc_26w']

# %% [markdown]
# > There is statistical difference after removing the values above 90%. T-test can confirm.

# %%
ttest_ind(x,y)
# Out:
# Ttest_indResult(statistic=1.2556513296043421, pvalue=0.2141103496655565)

# %%
plt.figure(figsize=(6,6)) 
# sb.pairplot(x_vars=['COGS_PRC_MTRC'], y_vars=['leak_26w'], data=data_brand,hue="BRX_GRX_CD", height=6,   plot_kws=dict(s=75))
g = sb.scatterplot(x='leak_26w', y='DSPN_COGS_NDC_26WKS', data=data_brand,hue="BRX_GRX_CD", size='leak_dol_26w', sizes = (50,425))
plt.xlabel("Leakage Rate")
plt.ylabel("Dollars of drugs dispensed per NDC")
# Out:
# Text(0, 0.5, 'Dollars of drugs dispensed per NDC')

# %%
x = data_count[['leak_dol_26w','leak_26w','NDC_DESC']][data_count['elviteg/cob/emtri/tenof']==1].sort_values(by='leak_dol_26w', ascending=False)
x.head(10)
# Out:
#        leak_dol_26w  leak_26w        NDC_DESC
# 16961  1.938607e+06  0.797872  GENVOYA TABLET
# 56371  1.401190e+06  0.690592  GENVOYA TABLET
# 49743  1.349122e+06  0.968902  GENVOYA TABLET
# 2433   7.183282e+05  0.953994  GENVOYA TABLET
# 59195  6.928176e+05  0.979592  GENVOYA TABLET
# 42757  6.350827e+05  0.543210  GENVOYA TABLET
# 30417  5.976147e+05  0.986003  GENVOYA TABLET
# 3253   5.372857e+05  0.693431  GENVOYA TABLET
# 79387  5.107825e+05  0.637796  GENVOYA TABLET
# 55850  5.054736e+05  0.550000  GENVOYA TABLET

# %% [markdown]
# ### _High-spending, branded items generally leak more and cost more in their leakage._
# ### _Generic items may leak at a higher percentage, but do not represent much loss._

# %%
# plt.figure(figsize=(6,6))
# sb.pairplot(x_vars=['leak_26w'], y_vars=['leak_dol_26w'], data=data_brand,hue="BRX_GRX_CD", height=6,   plot_kws=dict(s=75))
# h = sb.scatterplot(x='leak_26w', y='COGS_PRC_MTRC', data=data_brand,hue="BRX_GRX_CD", size='leak_dol_26w', sizes = (50,450))

# %%
data_brx = data_brand[data_brand['BRX_GRX_CD'] == 'BRX']
data_grx = data_brand[data_brand['BRX_GRX_CD'] == 'GRX']

# %%
# plt.figure(figsize=(10,10))
# # sb.pairplot(x_vars=['leak_26w'], y_vars=['leak_dol_26w'], data=data_brand,hue="BRX_GRX_CD", height=6,   plot_kws=dict(s=75))
# # m = sb.scatterplot(x='leak_26w', y='leak_dol_26w', data=data_brand,hue="BRX_GRX_CD", size='leak_dol_26w', sizes = (50,450))
# m = sb.regplot(x="leak_26w", y="COGS_PRC_MTRC", data=data_brx)

# %% [markdown]
# * Branded medicine suprisingly does not have high leakage rate, but represents a higher dollar value that can be captured.

# %% [markdown]
# Lower-priced generics have lower perc -> Higher leakage

# %% [markdown]
# Quartiles -> To make sure that the big ones stay in one chart

# %% [markdown]
# ### 3. Buying Groups

# %%
plt.figure(figsize=(10,10))
b = sb.scatterplot(x='leak_26w', y='COGS_PRC_MTRC', data=data_brand,hue="BUY_GRP_NAM", size='leak_dol_26w', sizes = (50,450)) 
plt.setp(b.get_legend().get_texts(), fontsize='12')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
data_buygroup = data.groupby('BUY_GRP_NAM').sum().reset_index()
getPerc(data_buygroup)

# %% [markdown]
# ## Use this to get back to [the start](#first-bullet)
# <a name='down'></a>

# %%
# data_buy_price = data[data['GCNSEQ_DESC'].str.contains('insulin|linagliptin|glargine,hum.rec.anlog|sitagliptin|dulaglutide|liraglutide')]
#get data on only CLIPPERS and WARRIERS, the two jugglenaughts
# data_2 = data[data['BUY_GRP_NAM'].str.contains('CLIPPERS|LAKERS')]
data_2 = data[data['BUY_GRP_NAM'].str.contains('WARRIERS|CLIPPERS')]

#Get price info on LANTUS SOLOSTAR
data_lan_solo = data_2[data_2['NDC_DESC'].str.contains('LANTUS 100 UNIT/ML VIAL')]
# data_lan_solo = data_lan_solo[data_lan_solo['DSPN_QTY_NDC_26WKS'] <5000]
data_lan_solo = data_lan_solo[data_lan_solo['COGS_PRC_MTRC'] >25.25]
data_lan_solo = data_lan_solo[data_lan_solo['leak_dol_26w'] >0]
data_lan_solo.loc[:,'leak_26w'] = data_lan_solo['leak_dol_26w']/data_lan_solo['DSPN_COGS_NDC_26WKS']

# %%
data_lan_solo[['DSPN_COGS_NDC_26WKS','sales_26w','leak_dol_26w','leak_26w']].head(10);

# %%
plt.figure(figsize=(7,7))
a = sb.scatterplot(x='leak_26w', y='COGS_PRC_MTRC', data=data_lan_solo,hue="BUY_GRP_NAM", size='leak_dol_26w', sizes=(75,320),alpha=0.9,legend=False)
# plt.setp(b.get_legend().get_texts(), fontsize='12')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Leak Rate')
plt.ylabel('Metric Price')
plt.savefig('lantus_solo.png', transparent=True)
# Out:
# No handles with labels found to put in legend.

# %%
#Get price info on LANTUS 100
data_lan = data_2[data_2['NDC_DESC'].str.contains('LANTUS 100')]

# %%
data_lan.loc[:,'leak_26w'] = data_lan.loc[:,'leak_dol_26w']/data_lan.loc[:,'DSPN_COGS_NDC_26WKS'];
# Out:
# c:\users\linhd\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)

# %%
data_lan = data_lan[data_lan['leak_dol_26w'] >0]
data_lan = data_lan[data_lan['COGS_PRC_MTRC'] >25.35]

# %%
data_lan[['DSPN_COGS_NDC_26WKS','sales_26w','leak_dol_26w']];

# %%
plt.figure(figsize=(7,7))
k = sb.scatterplot(x='leak_26w', y='COGS_PRC_MTRC', data=data_lan,hue="BUY_GRP_NAM", size='leak_dol_26w', sizes=(75,320),alpha=0.9)
# plt.setp(b.get_legend().get_texts(), fontsize='12')\
plt.xlabel('Leak')
plt.ylabel('Metric Price')
# Out:
# Text(0, 0.5, 'Metric Price')

# %%
#Get price info on LEVEMIR FLEXTOUCH
data_levemir = data_2[data_2['NDC_DESC'].str.contains('NOVOLOG 100 UNITS/ML FLEXPEN')]
data_levemir = data_levemir[data_levemir['COGS_PRC_MTRC'] >35]
data_levemir = data_levemir[data_levemir['leak_dol_26w'] >0]
data_levemir.loc[:,'leak_26w'] = data_levemir['leak_dol_26w']/data_levemir['DSPN_COGS_NDC_26WKS']
data_levemir.sort_values(by='BUY_GRP_NAM', ascending=False);

# %%
plt.figure(figsize=(7,7))
k = sb.scatterplot(x='leak_26w', y='COGS_PRC_MTRC', data=data_levemir,hue="BUY_GRP_NAM", size='leak_dol_26w', sizes=(75,320),alpha=0.9, legend=False)
plt.xlabel('Leak Rate')
plt.ylabel('Metric Price')
plt.savefig('lantus_novolog.png', transparent=True)

# %%
#Get price info on JANUVIA
data_janu = data_2[data_2['NDC_DESC'].str.contains('JANUVIA')]
data_janu = data_janu[data_janu['COGS_PRC_MTRC'] >13]
data_janu = data_janu[data_janu['leak_dol_26w'] >0]
data_janu.loc[:,'leak_26w'] = data_janu['leak_dol_26w']/data_janu['DSPN_COGS_NDC_26WKS']

# %%
plt.figure(figsize=(7,7))
k = sb.scatterplot(x='leak_26w', y='COGS_PRC_MTRC', data=data_janu,hue="BUY_GRP_NAM", size='leak_dol_26w', sizes=(65,320))
# plt.setp(b.get_legend().get_texts(), fontsize='12')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Dispensed Total Value')
plt.ylabel('Metric Price')
# Out:
# Text(0, 0.5, 'Metric Price')

# %%
#Get price info on TRADJENTA
data_trad = data_2[data_2['NDC_DESC'].str.contains('TRADJENTA')]
data_trad = data_trad[data_trad['COGS_PRC_MTRC'] >12.75]
data_trad = data_trad[data_trad['leak_dol_26w'] >0]
data_trad.loc[:,'leak_26w'] = data_trad['leak_dol_26w']/data_trad['DSPN_COGS_NDC_26WKS']

# %%
plt.figure(figsize=(7,7))
k = sb.scatterplot(x='leak_26w', y='COGS_PRC_MTRC', data=data_trad,hue="BUY_GRP_NAM", size='leak_dol_26w', sizes=(75,320),alpha=0.9)
# plt.setp(b.get_legend().get_texts(), fontsize='12')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Dispensed Total Value')
plt.ylabel('Metric Price')
# Out:
# Text(0, 0.5, 'Metric Price')

# %%
#Get price info on VICTOZA 2-PAK 
data_vic = data_2[data_2['NDC_DESC'].str.contains('VICTOZA 3-PAK')]
# data_vic = data_vic[data_vic['COGS_PRC_MTRC'] >12.75]
data_vic = data_vic[data_vic['leak_dol_26w'] >0]
data_vic = data_vic[data_vic['leak_dol_26w'] <25000]
data_vic = data_vic[data_vic['COGS_PRC_MTRC'] > 91]
data_vic.loc[:,'leak_26w'] = data_vic['leak_dol_26w']/data_vic['DSPN_COGS_NDC_26WKS']

# %%
plt.figure(figsize=(7,7))
k = sb.scatterplot(x='leak_26w', y='COGS_PRC_MTRC', data=data_vic,hue="BUY_GRP_NAM", size='leak_dol_26w', sizes=(75,320),alpha=0.9, legend=False)
# plt.setp(b.get_legend().get_texts(), fontsize='12')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('Leak Rate')
plt.ylabel('Metric Price')
plt.savefig('lantus_victoza.png', transparent=True)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## What's with SPURS

# %% [markdown]
# ## A unifying predictive model

# %% [markdown]
# <b>Tentative features:</b>
# * Key ingredients (combine ingredients that always go together)
# * Buying group (make them dummy variables too)
# * DSPN dollars
# * A measure of price (which accounts for actual, reasonable units)
# * Branded / Generic
#
# <b>Target:</b>
# * Leak Dol
#
#
# <em><b>Try Ridge Regression first, then support vector</b></em>
